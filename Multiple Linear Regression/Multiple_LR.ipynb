# %%
'''
It is similar to Simple Linear Regression but there are more than one features 
hence its not 1d and there is no line there is plane or hyperplane which cut the point it that way 
it cover all points closely as data is not properly linear

Equation of the plane is y = m*x1 + n*x2 + b  it can be y = b0 + b1x1 + b2x2 + ...... + bnxn

here m, n and b1, b2, .... act as weights similar as Simple LR


'''
