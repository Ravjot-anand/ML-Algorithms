# %%
import numpy as np 
import pandas as pd
from sklearn.ensemble import VotingRegressor

# %%
from sklearn.datasets import make_regression
X, y = make_regression(n_samples=506, n_features=13, noise=0.1, random_state=42)

print(X.shape, y.shape)
# Out:
# (506, 13) (506,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
svr = SVR()

# %%
estimators = [
    ('lr', lr),
    ('dt', dt),
    ('svr', svr)
]

print(type(estimators))
print(estimators)
# Out:
# <class 'list'>
# [('lr', LinearRegression()), ('dt', DecisionTreeRegressor()), ('svr', SVR())]

# %%
vr = VotingRegressor(estimators=estimators)

scores = cross_val_score(vr, X, y, scoring='r2', cv=10)
print("Voting Regressor", np.round(np.mean(scores), 2))
# Out:
# Voting Regressor 0.75

# %%
#applying weights
for i in range(1,4):
  for j in range(1,4):
    for k in range(1,4):
      vr = VotingRegressor(estimators,weights=[i,j,k])
      scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
      print("For i={},j={},k={}".format(i,j,k),np.round(np.mean(scores),2))
# Out:
# For i=1,j=1,k=1 0.75
# For i=1,j=1,k=2 0.64
# For i=1,j=1,k=3 0.56
# For i=1,j=2,k=1 0.7
# For i=1,j=2,k=2 0.63
# For i=1,j=2,k=3 0.59
# For i=1,j=3,k=1 0.67
# For i=1,j=3,k=2 0.63
# For i=1,j=3,k=3 0.59
# For i=2,j=1,k=1 0.86
# For i=2,j=1,k=2 0.77
# For i=2,j=1,k=3 0.69
# For i=2,j=2,k=1 0.81
# For i=2,j=2,k=2 0.75
# For i=2,j=2,k=3 0.7
# For i=2,j=3,k=1 0.76
# For i=2,j=3,k=2 0.73
# For i=2,j=3,k=3 0.68
# For i=3,j=1,k=1 0.91
# For i=3,j=1,k=2 0.84
# For i=3,j=1,k=3 0.77
# For i=3,j=2,k=1 0.87
# For i=3,j=2,k=2 0.82
# For i=3,j=2,k=3 0.77
# For i=3,j=3,k=1 0.82
# For i=3,j=3,k=2 0.79
# For i=3,j=3,k=3 0.75

# %%
for estimators in estimators:
    scores = cross_val_score(estimators[1],X,y,cv=10,scoring='r2')
    print(f"({estimators[0]}) R2 Score: {np.mean(scores)}")

# %%
#Using same Algo and improving it through Voting Regressor
dt1 = DecisionTreeRegressor(max_depth=1)
dt2 = DecisionTreeRegressor(max_depth=3)
dt3 = DecisionTreeRegressor(max_depth=5)
dt4 = DecisionTreeRegressor(max_depth=7)
dt5 = DecisionTreeRegressor(max_depth=None)
#here we are using same algo but with different hyperparameters

# %%
estimators = [('dt1',dt1),('dt2',dt2),('dt3',dt3),('dt4',dt4),('dt5',dt5)]

# %%
for estimator in estimators:
  scores = cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
  print(estimator[0],np.round(np.mean(scores),2))
# Out:
# dt1 0.2
# dt2 0.38
# dt3 0.42
# dt4 0.41
# dt5 0.38

# %%
vr = VotingRegressor(estimators)
scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
print("Voting Regressor",np.round(np.mean(scores),2))
# Out:
# Voting Regressor 0.51
