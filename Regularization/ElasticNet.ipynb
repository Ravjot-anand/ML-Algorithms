# %%
#Regularization technique combiines both Ridge and lasso(L1+L2)
'''
formula goes like loss function = MSE + a||W||^2 + b|W|
and the hyperparameters are 
lambda = a + b
l1_ratio = a / a + b

l1_ratio = a / lambda
'''

#we can use elastic net when there is multicolinearity in data means the one feature depends fully on other
# Out:
# '\nformula goes like loss function = MSE + a||W||^2 + b|W|\nand the hyperparameters are \nlambda = a + b\nl1_ratio = a / a + b\n'

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import Ridge,LinearRegression,Lasso,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
#Linear Regression 
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
#Ridge
R = Ridge(alpha=0.1)
R.fit(X_train,y_train)
y_pred = R.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.44828039822699206

# %%
#Lasso 
la = Lasso(alpha=0.01)
la.fit(X_train,y_train)
y_pred = la.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.441118559631106

# %%
#Elastic Net 
reg = ElasticNet(alpha=0.005,l1_ratio=0.9)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4531474541554822

# %%
a = 0.9*0.005 # a
print(a)
# Out:
# 0.0045000000000000005

# %%
b = 0.005 - a 
print(b)
# Out:
# 0.0004999999999999996

# %%
a+b
# Out:
# 0.005
